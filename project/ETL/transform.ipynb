# %%
import pandas as pd

# %%
unemployment_pre = pd.read_csv(r"D:\\Github\\made-ws23\\project\\data\\data\\API_SL.UEM.TOTL.ZS_DS2_en_csv_v2_6299762.csv", skiprows = 3)
crime_pre = pd.read_csv(r"D:\\Github\\made-ws23\\project\\data\\data\\API_VC.IHR.PSRC.P5_DS2_en_csv_v2_6299884.csv", skiprows = 3)

# %% [markdown]
# Unemployment data pre-processing

# %%
#Finding columns with all null values
unemployment_pre.columns[unemployment_pre.isna().all()].tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', 'Unnamed: 67'],
#       dtype='object')>

# %%
#Dropping columns with Null values
unemployment_pre.drop(columns=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990','2022', 'Unnamed: 67'], inplace = True)

# %%
#Dropping columns with no significant meaning
unemployment_pre.drop(columns = ['Country Code', 'Indicator Name', 'Indicator Code'], inplace = True)

# %%
#Finding rows with all null values
unemployment_pre[unemployment_pre.loc[:, '1991':].isna().all(axis =1)].index
# Out:
# Int64Index([  0,   6,  11,  12,  27,  51,  52,  57,  78,  79,  84,  90,  91,
#             108, 110, 124, 125, 137, 147, 149, 155, 164, 179, 188, 212, 225,
#             226, 228, 245, 255, 261],
#            dtype='int64')

# %%
#Dropping rows with all null values
unemployment_pre.drop(index=[0,   6,  11,  12,  27,  51,  52,  57,  78,  79,  84,  90,  91,
            108, 110, 124, 125, 137, 147, 149, 155, 164, 179, 188, 212, 225,
            226, 228, 245, 255, 261], inplace = True)

# %%
unemployment_pre
# Out:
#                     Country Name       1991       1992       1993       1994  \
# 1    Africa Eastern and Southern   7.333336   7.318747   7.242705   7.160694
# 2                    Afghanistan   8.121000   8.168000   8.123000   8.111000
# 3     Africa Western and Central   4.224595   4.335460   4.372125   4.366898
# 4                         Angola   4.489000   4.487000   4.531000   4.395000
# 5                        Albania  10.307000  30.015000  25.258000  20.840000
# ..                           ...        ...        ...        ...        ...
# 260                        Samoa   2.100000   2.385000   2.632000   3.040000
# 262                  Yemen, Rep.   8.342000   8.325000   8.365000   8.340000
# 263                 South Africa  21.194000  21.159000  20.971000  20.828000
# 264                       Zambia  18.900000  19.460000  19.700000  18.679000
# 265                     Zimbabwe   4.997000   5.069000   5.010000   4.960000
#
# ...

# %%
unemployment_pre.isnull().any()
# Out:
# Country Name    False
# 1991            False
# 1992            False
# 1993            False
# 1994            False
# 1995            False
# 1996            False
# 1997            False
# 1998            False
# 1999            False
# 2000            False
# 2001            False
# 2002            False
# 2003            False
# 2004            False
# 2005            False
# 2006            False
# 2007            False
# 2008            False
# 2009            False
# 2010            False
# 2011            False
# 2012            False
# 2013            False
# 2014            False
# 2015            False
# 2016            False
# 2017            False
# 2018            False
# 2019            False
# 2020            False
# 2021             True
# dtype: bool

# %%
#transpose
unemployment_pre.transpose()
# Out:
#                                       1            2    \
# Country Name  Africa Eastern and Southern  Afghanistan
# 1991                             7.333336        8.121
# 1992                             7.318747        8.168
# 1993                             7.242705        8.123
# 1994                             7.160694        8.111
# 1995                             7.063796         8.26
# 1996                             7.055998        8.165
# 1997                             7.090541        8.089
# 1998                             7.060096        8.082
# 1999                             7.015271         8.07
# 2000                             6.939536        8.054
# 2001                             6.850376         8.04
# 2002                             6.803537        8.186
# 2003                             6.741241        8.122
# 2004                             6.535173        8.053
# 2005                             6.373503        8.113
# ...

# %%
unemployment_pre.describe()
# Out:
#              1991        1992        1993        1994        1995        1996  \
# count  235.000000  235.000000  235.000000  235.000000  235.000000  235.000000
# mean     7.203454    7.540393    7.960158    8.134804    8.205945    8.362589
# std      5.558514    5.852712    5.893973    5.816435    5.893918    5.929165
# min      0.600000    0.661000    0.637000    0.645000    0.647000    0.640000
# 25%      3.005000    3.251000    3.719000    4.010000    4.036000    4.098336
# 50%      5.804886    5.919228    6.123000    6.550999    7.063796    7.141000
# 75%      9.764504   10.176000   10.842606   11.095000   10.980617   11.329000
# max     29.887000   30.015000   29.745000   30.000000   35.600000   38.800000
#
#              1997        1998        1999        2000  ...        2012  \
# count  235.000000  235.000000  235.000000  235.000000  ...  235.000000
# mean     8.260554    8.309534    8.442746    8.320795  ...    7.992262
# ...

# %% [markdown]
# # Crime data pre-processing

# %%
#Finding columns with all null values
crime_pre.columns[crime_pre.isna().all()].tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '2022', 'Unnamed: 67'],
#       dtype='object')>

# %%
#Dropping columns with Null values
crime_pre.drop(columns=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '2022', 'Unnamed: 67'], inplace = True)

# %%
#Dropping columns with no significant meaning
crime_pre.drop(columns = ['Country Code', 'Indicator Name', 'Indicator Code'], inplace = True)

# %%
crime_pre
# Out:
#                     Country Name     1991      1992      1993       1994  \
# 0                          Aruba      NaN       NaN       NaN        NaN
# 1    Africa Eastern and Southern      NaN       NaN       NaN        NaN
# 2                    Afghanistan      NaN       NaN       NaN        NaN
# 3     Africa Western and Central      NaN       NaN       NaN        NaN
# 4                         Angola      NaN       NaN       NaN        NaN
# ..                           ...      ...       ...       ...        ...
# 261                       Kosovo      NaN       NaN       NaN        NaN
# 262                  Yemen, Rep.      NaN       NaN       NaN        NaN
# 263                 South Africa      NaN       NaN       NaN  60.009733
# 264                       Zambia  8.67969  9.511616  9.007465   9.806217
# 265                     Zimbabwe      NaN       NaN       NaN        NaN
#
#           1995       1996       1997       1998       1999  ...       2012  \
# ...

# %%
# Finding countries where total null values are greater than 5 starting from 1990 to 2021
countries_with_nulls = crime_pre[crime_pre.loc[:, '1991':].isna().sum(axis=1) > 5]

# Drop the countries having NAN values greater than 6
crime_pre_cleaned = crime_pre.drop(countries_with_nulls[countries_with_nulls.sum(axis=1) > 6].index)

# List of remaining countries
remaining_countries = crime_pre_cleaned['Country Name'].tolist()

# Total count of remaining countries
total_remaining_countries = len(remaining_countries)

# Print the results
print("Remaining Countries:")
print(remaining_countries)
print("\nTotal Count of Remaining Countries:", total_remaining_countries)
# Out:
# Remaining Countries:
# ...

# %%
print(crime_pre_cleaned)
# Out:
#                        Country Name       1991       1992       1993  \
# 5                           Albania        NaN   3.934936   5.786633
# 10                          Armenia   5.141486   8.532529   7.751603
# 13                        Australia   1.968608   1.723693   1.888664
# 14                          Austria   1.328066   1.237116   1.011982
# 15                       Azerbaijan   4.735836   7.378975   6.175625
# ..                              ...        ...        ...        ...
# 251                   United States   9.819916   9.311245   9.477558
# 253  St. Vincent and the Grenadines  15.960277  15.898041  12.321666
# 254                   Venezuela, RB  12.370086  15.777427  20.271962
# 258                         Vanuatu        NaN        NaN        NaN
# 263                    South Africa        NaN        NaN        NaN
#
#           1994       1995       1996       1997       1998       1999  ...  \
# ...

# %%
# Fill NaN values in columns with their mean
crime_pre_cleaned_filled = crime_pre_cleaned.fillna(crime_pre_cleaned.mean())

# Print the cleaned and filled data
print("Cleaned and Filled Crime Dataset:")
print(crime_pre_cleaned_filled)
# Out:
# Cleaned and Filled Crime Dataset:
#                        Country Name       1991       1992       1993  \
# 5                           Albania   7.469486   3.934936   5.786633
# 10                          Armenia   5.141486   8.532529   7.751603
# 13                        Australia   1.968608   1.723693   1.888664
# 14                          Austria   1.328066   1.237116   1.011982
# 15                       Azerbaijan   4.735836   7.378975   6.175625
# ..                              ...        ...        ...        ...
# 251                   United States   9.819916   9.311245   9.477558
# 253  St. Vincent and the Grenadines  15.960277  15.898041  12.321666
# 254                   Venezuela, RB  12.370086  15.777427  20.271962
# 258                         Vanuatu   7.469486   8.189933   8.509661
# 263                    South Africa   7.469486   8.189933   8.509661
#
#           1994       1995       1996       1997       1998       1999  ...  \
# ...

# %%
#transpose
crime_pre_cleaned_filled.isnull().all()
# Out:
# Country Name    False
# 1991            False
# 1992            False
# 1993            False
# 1994            False
# 1995            False
# 1996            False
# 1997            False
# 1998            False
# 1999            False
# 2000            False
# 2001            False
# 2002            False
# 2003            False
# 2004            False
# 2005            False
# 2006            False
# 2007            False
# 2008            False
# 2009            False
# 2010            False
# 2011            False
# 2012            False
# 2013            False
# 2014            False
# 2015            False
# 2016            False
# 2017            False
# 2018            False
# 2019            False
# 2020            False
# 2021            False
# dtype: bool

# %%
crime_pre_cleaned_filled.shape
# Out:
# (112, 32)

# %% [markdown]
# # removing extra countries from unemployment data to sync with crime data

# %%
remaining_countries = ['Albania', 'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Benin', 'Bulgaria', 'Bahamas, The', 'Bermuda', 'Brazil', 'Barbados', 'Bhutan', 'Canada', 'Central Europe and the Baltics', 'Channel Islands', "Cote d'Ivoire", 'Congo, Dem. Rep.', 'Congo, Rep.', 'Colombia', 'Comoros', 'Costa Rica', 'Cuba', 'Cayman Islands', 'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominican Republic', 'East Asia & Pacific (excluding high income)', 'Ecuador', 'Euro area', 'Spain', 'Estonia', 'European Union', 'Finland', 'France', 'Faroe Islands', 'Micronesia, Fed. Sts.', 'Gabon', 'United Kingdom', 'Gibraltar', 'Guinea', 'Gambia, The', 'Guinea-Bissau', 'Equatorial Guinea', 'Greece', 'Guatemala', 'Guyana', 'Hong Kong SAR, China', 'Honduras', 'Croatia', 'Hungary', 'Indonesia', 'India', 'Not classified', 'Ireland', 'Iceland', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Kyrgyz Republic', 'Korea, Rep.', 'Lao PDR', 'Libya', 'St. Lucia', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao SAR, China', 'Morocco', 'Monaco', 'Moldova', 'Madagascar', 'Mexico', 'Mali', 'Malta', 'Northern Mariana Islands', 'Mauritania', 'Malaysia', 'Nicaragua', 'Netherlands', 'Norway', 'Nauru', 'New Zealand', 'Pakistan', 'Panama', 'Poland', 'Puerto Rico', "Korea, Dem. People's Rep.", 'Qatar', 'Romania', 'Russian Federation', 'Senegal', 'Singapore', 'El Salvador', 'San Marino', 'Somalia', 'Slovak Republic', 'Slovenia', 'Sweden', 'Sint Maarten (Dutch part)', 'Chad', 'East Asia & Pacific (IDA & IBRD countries)', 'Togo', 'Ukraine', 'Uruguay', 'United States', 'St. Vincent and the Grenadines', 'Venezuela, RB', 'Vanuatu', 'South Africa']
# Filter the rows for the remaining countries
unemployment_remaining_countries = unemployment_pre[unemployment_pre['Country Name'].isin(remaining_countries)]

# Print the DataFrame for remaining countries
print("Unemployment Data for Remaining Countries:")
print(unemployment_remaining_countries)
# Out:
# Unemployment Data for Remaining Countries:
#                        Country Name    1991    1992    1993    1994    1995  \
# 5                           Albania  10.307  30.015  25.258  20.840  14.611
# 10                          Armenia   1.600   1.800   5.300   6.600   6.700
# 13                        Australia   9.580  10.730  10.870   9.720   8.470
# 14                          Austria   3.420   3.590   4.250   3.540   4.340
# 15                       Azerbaijan   0.900   1.800   4.500   6.300   7.200
# ..                              ...     ...     ...     ...     ...     ...
# 251                   United States   6.800   7.500   6.900   6.120   5.650
# 253  St. Vincent and the Grenadines  19.770  19.734  19.802  20.185  20.059
# 254                   Venezuela, RB   9.450   7.690   6.600   8.560  10.240
# 258                         Vanuatu   1.734   1.751   1.797   1.622   1.800
# 263                    South Africa  21.194  21.159  20.971  20.828  20.750
#
# ...

# %%
unemployment_remaining_countries.transpose()
# Out:
#                   5        10         13       14          15     18   \
# Country Name  Albania  Armenia  Australia  Austria  Azerbaijan  Benin
# 1991           10.307      1.6       9.58     3.42         0.9  1.484
# 1992           30.015      1.8      10.73     3.59         1.8   1.51
# 1993           25.258      5.3      10.87     4.25         4.5  1.396
# 1994            20.84      6.6       9.72     3.54         6.3  1.358
# 1995           14.611      6.7       8.47     4.34         7.2  1.237
# 1996           13.931      9.3       8.51     5.28         8.1  1.175
# 1997           16.876     10.8       8.36     5.15         9.1  1.083
# 1998           20.047      9.4       7.68     5.48        10.0  1.018
# 1999            20.84     11.2       6.87      4.7        10.9  0.927
# 2000           19.028   11.055       6.28     4.69       11.78  0.843
# 2001           18.575   10.933       6.74     4.01       10.91  0.766
# ...

# %%
unemployment_remaining_countries.columns
# Out:
# Index(['Country Name', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
u = unemployment_remaining_countries.set_index('Country Name').T.columns.tolist()
c = crime_pre_cleaned_filled.set_index('Country Name').T.columns.tolist()
temp = [x for x in c if x not in u]
print(temp)
# Out:
# ['Bermuda', 'Cayman Islands', 'Faroe Islands', 'Micronesia, Fed. Sts.', 'Gibraltar', 'Not classified', 'Liechtenstein', 'Monaco', 'Northern Mariana Islands', 'Nauru', 'San Marino', 'Sint Maarten (Dutch part)']

# %%
crime_skim = crime_pre_cleaned_filled.set_index('Country Name').T
crime_skim.drop(columns = ['Bermuda', 'Cayman Islands', 'Faroe Islands', 'Micronesia, Fed. Sts.', 'Gibraltar', 'Not classified', 'Liechtenstein', 'Monaco', 'Northern Mariana Islands', 'Nauru', 'San Marino', 'Sint Maarten (Dutch part)'], inplace = True)
crime_skim
# Out:
# Country Name    Albania    Armenia  Australia   Austria  Azerbaijan  \
# 1991           7.469486   5.141486   1.968608  1.328066    4.735836
# 1992           3.934936   8.532529   1.723693  1.237116    7.378975
# 1993           5.786633   7.751603   1.888664  1.011982    6.175625
# 1994           3.400123   4.653626   1.797197  1.108960    6.379541
# 1995           7.885849   3.491050   1.977448  0.981466    5.615179
# 1996           8.314658   3.455700   1.943790  1.244025    5.032015
# 1997          40.999238   3.056778   1.977159  0.828408    3.549973
# 1998          20.419683   2.869883   1.795538  0.965413    3.482113
# 1999          16.582197   2.807211   2.047775  0.750809    2.987120
# 2000           4.116881   2.872000   1.903464  1.023666    2.759349
# 2001           6.976128   2.808690   1.802771  0.870687    2.632207
# 2002           6.915206   2.222195   1.879251  0.804556    2.532212
# 2003           5.366973  10.690800   1.533073  0.615756   10.690800
# ...

# %%
crime_final = crime_skim.T.reset_index()
crime_final
# Out:
#                       Country Name       1991       1992       1993  \
# 0                          Albania   7.469486   3.934936   5.786633
# 1                          Armenia   5.141486   8.532529   7.751603
# 2                        Australia   1.968608   1.723693   1.888664
# 3                          Austria   1.328066   1.237116   1.011982
# 4                       Azerbaijan   4.735836   7.378975   6.175625
# ..                             ...        ...        ...        ...
# 95                   United States   9.819916   9.311245   9.477558
# 96  St. Vincent and the Grenadines  15.960277  15.898041  12.321666
# 97                   Venezuela, RB  12.370086  15.777427  20.271962
# 98                         Vanuatu   7.469486   8.189933   8.509661
# 99                    South Africa   7.469486   8.189933   8.509661
#
#          1994       1995       1996       1997       1998       1999  ...  \
# 0    3.400123   7.885849   8.314658  40.999238  20.419683  16.582197  ...
# ...

# %%
unemployment_final = unemployment_remaining_countries.reset_index(drop = True)
unemployment_final
# Out:
#                       Country Name    1991    1992    1993    1994    1995  \
# 0                          Albania  10.307  30.015  25.258  20.840  14.611
# 1                          Armenia   1.600   1.800   5.300   6.600   6.700
# 2                        Australia   9.580  10.730  10.870   9.720   8.470
# 3                          Austria   3.420   3.590   4.250   3.540   4.340
# 4                       Azerbaijan   0.900   1.800   4.500   6.300   7.200
# ..                             ...     ...     ...     ...     ...     ...
# 95                   United States   6.800   7.500   6.900   6.120   5.650
# 96  St. Vincent and the Grenadines  19.770  19.734  19.802  20.185  20.059
# 97                   Venezuela, RB   9.450   7.690   6.600   8.560  10.240
# 98                         Vanuatu   1.734   1.751   1.797   1.622   1.800
# 99                    South Africa  21.194  21.159  20.971  20.828  20.750
#
# ...

# %%
# Save transformed and transposed data to CSV files
unemployment_final.to_csv(r'D:\Github\made-ws23\project\data\data\unemployment.csv', index=False)
crime_final.to_csv(r'D:\Github\made-ws23\project\data\data\crime.csv', index=False)
